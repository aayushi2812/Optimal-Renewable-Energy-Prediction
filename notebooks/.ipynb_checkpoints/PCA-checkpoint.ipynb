# %%
# [EDA & Insights for City_Optimized.csv]

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Styling for notebook
plt.style.use("seaborn-v0_8-white")
sns.set_palette("colorblind")
pd.options.display.float_format = '{:,.2f}'.format

# LOAD DATA
df = pd.read_csv("City_Optimized.csv")

###########################
# 1. Basic Overview
###########################

print("==== DATA SNAPSHOT ====\n")
display(df.head())
print("\n===== Columns =====\n", df.columns.tolist())
print("\n=== Shape ===\n", df.shape)

###########################
# 2. Data Summary by Domain
###########################
def check_missing_and_unique(df):
    print("\n=== Missing Values & Unique Count ===\n")
    display(df.isna().sum().to_frame('missing').join(
        df.nunique().to_frame('unique')
    ))

check_missing_and_unique(df)
print("\n=== Descriptive (Numerical) ===")
display(df.describe(percentiles=[.05, .25, .5, .75, .95]).T)

############################
# 3. DOMAIN PROFILES
############################

# Group columns by practical pillar
pillar_energy = [c for c in df.columns if "solar" in c or "wind" in c or "hydro" in c or "geo" in c or "biomass" in c or "renewable" in c or "fossil" in c or "emission" in c or "carbon" in c]
pillar_economy = ["gdp_per_capita", "avg_household_income", "tax_revenue_per_capita", "cost_of_living_index", "population", "population_density", "annual_rainfall"]
pillar_climate = ["avg_temperature", "temperature_range", "avg_humidity", "cloud_cover_percentage", "air_quality_index"]
pillar_infrastructure = ["grid_infrastructure_quality", "grid_reliability_score", "energy_storage_capacity", "maintenance_cost_index", "installation_cost_index", "transmission_infrastructure"]
pillar_urban = [c for c in df.columns if "urban" in c or "density" in c or "skilled" in c or "technology" in c]
pillar_policy = ["govt_renewable_subsidy", "political_stability", "permitting_efficiency", "environmental_policy_strength", "renewable_target_2030", "rd_spending"]

##############################
# 4. CITY TYPOLOGY EXPLORATION
##############################

# a. City by Region Heatmap – Diverging color for Renewable vs Fossil dependency
renew_region = df.groupby("continent")[["current_renewable_percentage", "fossil_fuel_dependency"]].mean().reset_index()
fig = px.imshow(
    renew_region.set_index("continent").T,
    color_continuous_scale=["#ff7c43", "#fff7e8", "#43a2ca"],
    title="Mean Renewables vs Fossil Dependency by Continent",
    text_auto=".1f"
)
fig.update_layout(height=350)
fig.show()

# b. Cluster: "Sustainable Urban Innovation" (Simple PCA/2D projection)
clustering_cols = [
    "current_renewable_percentage", "fossil_fuel_dependency", "grid_infrastructure_quality",
    "population_density", "urban_density_score", "skilled_workforce_percentage", "technology_adoption_rate",
    "gdp_per_capita", "avg_temperature", "air_quality_index", "carbon_emissions_per_capita"
]
clust_data = df[clustering_cols].dropna()
# Standardize
X = StandardScaler().fit_transform(clust_data)
pca = PCA(n_components=2)
pca_out = pca.fit_transform(X)
plt.figure(figsize=(7,5))
plt.scatter(
    x=pca_out[:,0], y=pca_out[:,1],
    c=np.log(df.loc[clust_data.index, "population"]+1),
    cmap="plasma", label="Population (log)", alpha=0.7
)
plt.xlabel("Urban Sustainability Pattern 1 (PCA1)")
plt.ylabel("Pattern 2 (PCA2)")
plt.title("Urban Sustainability Typology (PCA Colored by Population)")
plt.colorbar(label='Log Population')
plt.grid(alpha=0.25)
plt.show()

##############################
# 5. ENERGY MIX & RENEWABLES
##############################
# a. Dominant Renewable Type Pie
dominant_re = df["optimal_renewable_energy"].value_counts()
fig = px.pie(
    dominant_re,
    names=dominant_re.index,
    values=dominant_re.values,
    color=dominant_re.index,
    color_discrete_map={
        "Solar":"#ffd500",
        "Wind":"#49a7df", "Hydropower":"#92e38a", "Biomass":"#a06c35", "Geothermal":"#c90076"
    },
    title="Dominant Renewable Energy Source (Count of Cities)"
)
fig.show()

# b. Cross-plot: Grid Quality vs Current Renewables w/ marker=GDP
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="grid_infrastructure_quality",
    y="current_renewable_percentage",
    hue="continent",
    size="gdp_per_capita",
    sizes=(20, 300),
    style="optimal_renewable_energy",
    palette="husl",
    data=df, alpha=0.7
)
plt.title("Grid Quality vs. Renewable Share")
plt.grid(alpha=0.2)
plt.show()

#############################
# 6. SOCIO-ECONOMIC LANDSCAPE
#############################
# Bubble plot: Population vs GDP/capita, colored by Air Quality

fig = px.scatter(
    df, x="population", y="gdp_per_capita", size="urban_density_score",
    color="air_quality_index", hover_name="city",
    title="City Socioeconomics: Population, GDP/capita, Urban Density & Air Quality",
    color_continuous_scale="haline"
)
fig.update_layout(xaxis_title="Population", yaxis_title="GDP per capita ($)")
fig.show()

############################
# 7. SPATIAL: CLIMATE VS ECONOMICS
############################
# Temperature (Y) vs GDP (X), bubble Population, color = Renewable Share
fig = px.scatter(
    df, x="gdp_per_capita", y="avg_temperature", size="population",
    color="current_renewable_percentage", hover_name="city",
    color_continuous_scale="Tealrose",
    title="Economic Wealth vs Climate: Bubble=Population, Color=Renewable %"
)
fig.update_layout(yaxis_title="Average Temp (°C)")
fig.show()

##############################
# 8. INFRASTRUCTURE RELIABILITY & POLICY
##############################

plt.figure(figsize=(8,6))
sns.violinplot(
    x="continent", y="grid_reliability_score",
    data=df, palette="Set3"
)
plt.title("Grid Reliability Score by Continent")
plt.grid(alpha=0.1)
plt.show()

plt.figure(figsize=(7,5))
sns.stripplot(
    data=df, x="optimal_renewable_energy", y="environmental_policy_strength",
    palette="tab10", alpha=0.8, jitter=True
)
plt.title("Environmental Policy Strength by Renewable Type")
plt.ylabel("Policy Strength Index")
plt.grid(alpha=0.25)
plt.show()

##############################
# 9. CORRELATION INSIGHTS
##############################
corr_cols = [
    "current_renewable_percentage", "grid_infrastructure_quality",
    "gdp_per_capita", "urban_density_score", "education_index",
    "technology_adoption_rate", "avg_temperature", "air_quality_index",
    "renewable_investment"
]
corr = df[corr_cols].corr()
plt.figure(figsize=(8,7))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="RdBu", center=0)
plt.title("Selected Feature Correlation Matrix")
plt.show()

##############################
# 10. HIGHLIGHTS & INSIGHTS
##############################
# Key automated takeaways — Best & Least
best_cities = df.sort_values("current_renewable_percentage", ascending=False).head(3)
print("\nTop Cities by Renewable Energy Share:\n", best_cities[["city", "country", "current_renewable_percentage", "optimal_renewable_energy"]])
worst_air = df.sort_values("air_quality_index", ascending=True).head(3)
print("\nBest Air Quality Cities:\n", worst_air[["city", "country", "air_quality_index"]])
top_policy = df.sort_values("environmental_policy_strength", ascending=False).head(3)
print("\nCities with Strongest Environmental Policy:\n", top_policy[["city", "country", "environmental_policy_strength"]])

#########################
# END OF EDA NOTEBOOK
#########################
# Out:
# ==== DATA SNAPSHOT ====
#      city_id      city country  latitude  longitude continent  \
# 0  CITY_0001     Tokyo   Japan     35.68     139.65      Asia
# 1  CITY_0002     Delhi   India     28.61      77.21      Asia
# 2  CITY_0003  Shanghai   China     31.23     121.47      Asia
# 3  CITY_0004    Mumbai   India     19.08      72.88      Asia
# 4  CITY_0005   Beijing   China     39.90     116.41      Asia
#
#    solar_irradiance_avg  peak_sun_hours  avg_wind_speed  wind_power_density  \
# 0                  2.76            2.22            1.91                  10
# 1                  3.64            2.96            4.91                  43
# 2                  3.73            2.63            3.13                  11
# 3                  5.49            4.57            2.41                  10
# 4                  3.78            3.44            5.70                  68
#
#    ...  installation_cost_index  maintenance_cost_index  political_stability  \
# ...

# %%
# Simple Domain-Aware EDA for City_Optimized.csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Formatting
plt.style.use('seaborn-v0_8-whitegrid')
pd.options.display.float_format = '{:,.2f}'.format

# Load data
df = pd.read_csv("City_Optimized.csv")

# --------- 1. Basic Overview ----------
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
display(df.head())

# --------- 2. Missing Values & Uniques ----------
print("\nMissing Values:\n", df.isna().sum())
print("\nUnique Value Count:\n", df.nunique())

# --------- 3. Key Numeric Summaries ----------
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
display(df[num_cols].describe().T)

# --------- 4. City Distribution by Continent ----------
continent_counts = df['continent'].value_counts()
continent_counts.plot(kind='bar', color=sns.color_palette('crest', n_colors=len(continent_counts)))
plt.title('Number of Cities by Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.show()

# --------- 5. Dominant Renewable Energy Type ----------
re_counts = df['optimal_renewable_energy'].value_counts()
fig = px.pie(df, names='optimal_renewable_energy', title='Dominant Renewable Energy Types')
fig.update_traces(textfont_size=14, marker=dict(line=dict(color='#000000', width=2)))
fig.show()

# --------- 6. Renewable vs Fossil Dependency ----------
fig, ax = plt.subplots(figsize=(7,5))
sns.histplot(df['current_renewable_percentage'], color='#43a047', label='Renewable %', kde=True, bins=16, alpha=0.7)
sns.histplot(df['fossil_fuel_dependency'], color='#c62828', label='Fossil %', kde=True, bins=16, alpha=0.5)
plt.title('Distribution: Renewable vs Fossil Dependency')
plt.xlabel('%')
plt.legend()
plt.show()

# --------- 7. GDP per Capita by Continent ----------
plt.figure(figsize=(9,5))
sns.boxplot(data=df, x='continent', y='gdp_per_capita', palette='Blues')
plt.title('GDP per Capita by Continent')
plt.ylabel('GDP per Capita ($)')
plt.xticks(rotation=30)
plt.show()

# --------- 8. Air Quality Index by Continent ----------
plt.figure(figsize=(9,5))
sns.boxplot(data=df, x='continent', y='air_quality_index', palette='Oranges')
plt.title('Air Quality Index by Continent')
plt.ylabel('Air Quality Index')
plt.xticks(rotation=30)
plt.show()

# --------- 9. Correlations: Energy & Environment ----------
corr_cols = ['current_renewable_percentage', 'grid_infrastructure_quality', 'gdp_per_capita', 'urban_density_score', 'education_index', 'avg_temperature', 'air_quality_index', 'carbon_emissions_per_capita']
plt.figure(figsize=(8,6))
sns.heatmap(df[corr_cols].corr(), annot=True, cmap='RdYlGn', center=0)
plt.title('Correlation (Energy, Environment, Socioeconomic)')
plt.show()

# --------- 10. Scatter: GDP per Capita vs Renewable Percentage ----------
plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x='gdp_per_capita', y='current_renewable_percentage', hue='continent', s=90, alpha=0.8)
plt.title('GDP per Capita vs. Renewable Percentage')
plt.xlabel('GDP per Capita ($)')
plt.ylabel('Renewable Electricity (%)')
plt.legend()
plt.show()

# --------- 11. Summary: Best and Challenged Cities ----------
print("\nTop 5 Cities by Renewable Energy Percentage:")
display(df[['city','country','current_renewable_percentage','optimal_renewable_energy']].sort_values('current_renewable_percentage', ascending=False).head())

print("\n5 Cities with Best Air Quality Index:")
display(df[['city','country','air_quality_index']].sort_values('air_quality_index', ascending=True).head())

print("\n5 Cities with Highest GDP per Capita:")
display(df[['city','country','gdp_per_capita']].sort_values('gdp_per_capita', ascending=False).head())

# --------- 12. Distribution of Technology Adoption Rate ----------
plt.figure(figsize=(7,4))
sns.histplot(df['technology_adoption_rate'], color='#1e88e5', bins=20)
plt.title('Distribution of Technology Adoption Rate (%)')
plt.xlabel('Technology Adoption Rate')
plt.show()

# --------- 13. Education Index by Continent ----------
plt.figure(figsize=(8,4))
sns.boxplot(data=df, x='continent', y='education_index', palette='Purples')
plt.title('Education Index by Continent')
plt.ylabel('Education Index (0-1)')
plt.xticks(rotation=30)
plt.show()

# --------- End of Simple Domain-Driven EDA ---------
# Out:
# Shape: (2000, 56)
# ...

# %%
# Domain-Driven EDA for City_Optimized.csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8-whitegrid')
pd.options.display.float_format = '{:,.2f}'.format

df = pd.read_csv("City_Optimized.csv")

# --- 1. High-Level Grouping of Features by Domain Knowledge ---

energy_cols = [
    "solar_irradiance_avg", "peak_sun_hours", "avg_wind_speed", "wind_power_density",
    "annual_rainfall", "river_proximity_score", "hydropower_potential", "geothermal_gradient",
    "current_renewable_percentage", "fossil_fuel_dependency", "optimal_renewable_energy",
    "solar_suitability_score", "wind_suitability_score", "hydro_suitability_score",
    "geothermal_suitability_score", "biomass_suitability_score", "energy_storage_capacity",
    "renewable_investment"
]

climate_cols = [
    "avg_temperature", "temperature_range", "avg_humidity", "cloud_cover_percentage",
    "air_quality_index", "carbon_emissions_per_capita"
]

urbanization_cols = [
    "population", "population_density", "urban_density_score", "available_land_area"
]

economy_cols = [
    "gdp_per_capita", "cost_of_living_index", "avg_household_income",
    "tax_revenue_per_capita", "unemployment_rate"
]

infra_policy_cols = [
    "grid_infrastructure_quality", "grid_reliability_score", "maintenance_cost_index",
    "installation_cost_index", "permitting_efficiency", "govt_renewable_subsidy",
    "environmental_policy_strength", "renewable_target_2030", "political_stability"
]

# --- 2. Derived/Grouped Features for More Insightful EDA ---
df["total_energy_suitability"] = df[[
    "solar_suitability_score",
    "wind_suitability_score",
    "hydro_suitability_score",
    "geothermal_suitability_score",
    "biomass_suitability_score"
]].mean(axis=1)

# Group storage & grid reliability:
df["infra_resilience_score"] = df[[
    "grid_infrastructure_quality","grid_reliability_score","energy_storage_capacity"
]].mean(axis=1)

# High income mask
df["is_high_income"] = df["gdp_per_capita"] > 40_000

# --- 3. Renewable Energy Mix Analysis ---

renewable_types = df["optimal_renewable_energy"].unique()
for typ in renewable_types:
    cnt = (df["optimal_renewable_energy"]==typ).sum()
    print(f"{typ:13}: {cnt} cities")

plt.figure(figsize=(8,4))
sns.countplot(x="optimal_renewable_energy", data=df, palette="tab20")
plt.title("Count: Optimal Renewable Energy Type per City")
plt.ylabel("Cities")
plt.xlabel("Main Renewable Type")
plt.show()

# --- 4. Grouped Suitability Analysis ---
suit_cols = ["solar_suitability_score", "wind_suitability_score",
             "hydro_suitability_score", "geothermal_suitability_score", "biomass_suitability_score"]
suit_means = df.groupby("optimal_renewable_energy")[suit_cols].mean()

suit_means.plot(kind='bar', colormap='tab20', figsize=(10,5))
plt.title("Mean Resource Suitability by Dominant Renewable Type")
plt.ylabel("Mean Suitability Score")
plt.xticks(rotation=30)
plt.show()

# --- 5. Urbanization vs. Infrastructure ---
plt.figure(figsize=(8,5))
sns.scatterplot(
    x="urban_density_score", y="infra_resilience_score",
    size="population", hue="is_high_income", data=df, alpha=0.7,
    palette=["#0496ff", "#e36414"]
)
plt.legend(title="High Income City?", loc='upper left')
plt.title("Urban Density vs Infrastructure Resilience (Size: Population)")
plt.xlabel("Urban Density Score")
plt.ylabel("Infra/Storage/Resilience Score")
plt.show()

# --- 6. Economic Grouping: GDP and Renewable Adoption ---

plt.figure(figsize=(9,5))
sns.boxplot(x="is_high_income", y="current_renewable_percentage",
            data=df, palette="crest")
plt.xticks([0,1],["Lower-Income","High-Income"])
plt.title("Renewable Share in Electricity: High vs Lower GDP/capita Cities")
plt.ylabel("Renewable Electricity Percentage")
plt.xlabel("City Type")
plt.show()

# --- 7. Climate-Energy Relationship ---
plt.figure(figsize=(8,5))
sns.scatterplot(
    data=df, x='avg_temperature', y='current_renewable_percentage',
    hue='optimal_renewable_energy', palette='Set2', alpha=0.8
)
plt.title("City Temp vs Renewable Energy Share (Color: Renewable Type)")
plt.ylabel("Current Renewable Share (%)")
plt.xlabel("Average Temperature (°C)")
plt.show()

# --- 8. Policy and Grid: Relationship Analysis ---

plt.figure(figsize=(9,5))
sns.scatterplot(
    x='environmental_policy_strength',
    y='grid_infrastructure_quality',
    hue='continent',
    size='technology_adoption_rate',
    palette='tab10',
    alpha=0.8, data=df
)
plt.title("Environmental Policy vs Grid Quality (Tech Adoption: Size)")
plt.xlabel("Environmental Policy Strength")
plt.ylabel("Grid Infrastructure Quality")
plt.legend(bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# --- 9. Correlation Heatmap for Thematic Groups ---

grouped_corr_cols = [
    "total_energy_suitability", "infra_resilience_score", "gdp_per_capita",
    "urban_density_score", "current_renewable_percentage", "air_quality_index", "avg_temperature",
    "technology_adoption_rate"
]
plt.figure(figsize=(8,6))
sns.heatmap(df[grouped_corr_cols].corr(), annot=True, cmap="RdBu", center=0)
plt.title("Correlation: Grouped Thematic Metrics")
plt.show()

# --- 10. Key Takeaways (Summary Tables for Management) ---

# By continent & by renewable
agg_summary = df.groupby(['continent', 'optimal_renewable_energy']).agg({
    'current_renewable_percentage':'mean',
    'infra_resilience_score':'mean',
    'urban_density_score':'mean',
    'gdp_per_capita':'mean',
    'air_quality_index':'mean'
}).round(1)
print("Mean values by Continent/Renewable Type:\n")
display(agg_summary.style.background_gradient(axis=0))

# --- 11. Top Performers by Grouped Metrics ---
print("\nTop 3 Cities in Each Thematic Category:\n")
for col in grouped_corr_cols:
    print(f"- {col}:")
    display(df[['city','country',col]].sort_values(col, ascending=False).head(3))

# End of Domain-Driven Grouped EDA
# Out:
# Biomass      : 459 cities
# Hydropower   : 212 cities
# Solar        : 702 cities
# Wind         : 345 cities
# Geothermal   : 282 cities
# /tmp/ipython-input-1858160030.py:68: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipython-input-1858160030.py:101: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Mean values by Continent/Renewable Type:
# <style type="text/css">
# #T_73a3f_row0_col0, #T_73a3f_row2_col3, #T_73a3f_row14_col1, #T_73a3f_row18_col0 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_73a3f_row0_col1 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load data
df = pd.read_csv("City_Optimized.csv")

# 1. Domain-driven Feature Selection
domain_features = [
    # Energy & Sustainability
    "current_renewable_percentage", "fossil_fuel_dependency",
    "solar_suitability_score", "wind_suitability_score", "hydro_suitability_score",
    "geothermal_suitability_score", "biomass_suitability_score",

    # Infrastructure quality/reliability
    "grid_infrastructure_quality", "grid_reliability_score", "energy_storage_capacity",

    # Socio-Economic & Urban
    "population_density", "urban_density_score", "gdp_per_capita", "education_index",
    "technology_adoption_rate",

    # Climate / Environmental
    "avg_temperature", "air_quality_index", "carbon_emissions_per_capita"
]
X_df = df[domain_features].copy().dropna()

# 2. Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X_df)

# 3. Fit PCA
pca = PCA()
pca.fit(X)
explained_var = np.cumsum(pca.explained_variance_ratio_)

n_components_90 = np.argmax(explained_var >= 0.95) + 1
print(f"Components for >=95% variance: {n_components_90}\n")

# 4. Scree Plot
plt.figure(figsize=(8,4))
plt.plot(np.arange(1, len(explained_var)+1), explained_var, marker='o', color="#1e88e5")
plt.axhline(0.95, color='gray', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Scree Plot (>=95% Variance Highlighted)')
plt.grid(alpha=0.4)
plt.show()

# 5. 2D PCA Scatter Plot
pca_2d = PCA(n_components=2)
X_pca2 = pca_2d.fit_transform(X)
plt.figure(figsize=(8,5))
sns.scatterplot(
    x=X_pca2[:,0], y=X_pca2[:,1],
    hue=df.loc[X_df.index, "continent"], style=df.loc[X_df.index, "optimal_renewable_energy"],
    s=80, alpha=0.8)
plt.title('Cities in Principal Component Space (PCA1 vs PCA2)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(bbox_to_anchor=(1,1))
plt.tight_layout(); plt.show()

# 6. PCA Loadings Plot (Feature Contributions to PC1 & PC2)
loadings = pd.DataFrame(
    pca_2d.components_.T,
    columns=['PCA1', 'PCA2'],
    index=domain_features
)
loadings_abs = loadings.abs().sum(axis=1).sort_values(ascending=False)
top_features = loadings_abs.head(8).index

loadings.loc[top_features, ['PCA1','PCA2']].plot(
    kind='barh', figsize=(9,4), cmap='Spectral'
)
plt.title('Top Feature Loadings for First Two Principal Components')
plt.xlabel('Loading Value (Absolute)')
plt.tight_layout(); plt.show()

# 7. Optional: PCA Reconstruction Errors (on 90% var components)
pca_90 = PCA(n_components=n_components_90)
X_pca90 = pca_90.fit_transform(X)
X_approx = pca_90.inverse_transform(X_pca90)
errors = np.abs(X - X_approx)
mean_error_by_feature = errors.mean(axis=0)
plt.figure(figsize=(10,3))
plt.bar(domain_features, mean_error_by_feature, color=sns.color_palette('crest'))
plt.ylabel("Mean Absolute Residual (std-units)")
plt.xticks(rotation=40, ha='right')
plt.title("Average Reconstruction Error by Feature Using PCA")
plt.tight_layout(); plt.show()
# Out:
# Components for >=95% variance: 13
